# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 5]

import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io


import numpy as np
import fnmatch
import os
import pandas as pd
import datetime

# %%
# Test period
startdate = '20211206'
#derp = datetime.datetime.strptime(startdate,'%Y%m%d')
print(startdate)
sdir = '/home/pookie/git/shorts/shortvolume/shortdata/'
prefix = 'CNMSshvol'
outputdir = '/home/pookie/git/shorts/shortvolume/shortdata/derp/'
# Out:
# 20211206

# %%
for file in os.listdir(sdir):
    matchme = prefix+str(startdate)+'*'
    #print(matchme, file)
    if fnmatch.fnmatch(file, matchme):
        filename = file

print(filename)
# Out:
# CNMSshvol20211206.txt

# %%
df = pd.read_csv(sdir+filename,sep="|")

# %%
Symbol = df['Symbol']

# %%
#Symbol[-2:len(Symbol)]
df.loc[df['Symbol'] == 'GME']
# Out:
#           Date Symbol  ShortVolume  ShortExemptVolume  TotalVolume Market
# 4021  20211206    GME     471069.0            14541.0     762959.0  B,Q,N

# %%
pwd
# Out:
# '/home/pookie/git/shorts'

# %%
f = outputdir+startdate
dirName = f
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206  already exists

# %%
print(startdate)
outputdir = f+'/'

for ticker in Symbol:
    sdf = df.loc[df['Symbol']== ticker]
    outputfilename = outputdir+ticker
    print(outputfilename)
    try:
        sdf.to_csv(outputfilename)
    except:
        print('error: {}'.format(ticker))
# Out:
# 20211206
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/A
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AA
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAA
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAAU
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAC
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAC/WS
# error: AAC/WS
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AACG
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AACI
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AACIW
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AADI
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AADR
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAIC
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAICpB
# /home/pookie/git/shorts/shortvolume/shortdata/derp/20211206/AAICpC
# ...
