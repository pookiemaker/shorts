# %%
# Setup environment to pull data from NASDAQ
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io

# Setup Boundaries.
# just a few days to testing
# set file storage location
dir =  '/home/pookie/data/historicdata/'

# get all the available tickers
url="https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed_csv/data/7665719fb51081ba0bd834fde71ce822/nasdaq-listed_csv.csv"
s = requests.get(url).content
companies = pd.read_csv(io.StringIO(s.decode('utf-8')))

# make the symbols list
Symbols = companies['Symbol'].tolist()

# create empty dataframe
stock_info = pd.DataFrame()# iterate over each symbol

# Download all the daily data for all symbols for the date range
for symbol in Symbols[:2]:

    # print the symbol which is being downloaded
    try:
        print('Downloading {}'.format(symbol))
        TICK = yf.Ticker(symbol).info
        
        stock_info = stock_info.append(TICK, ignore_index=True)
        print(stock_info.head())
        
    except:
        print('Downloading Error {}'.format(symbol))

# save the data to a file for later use
stock_info.to_csv(dir+'StockInfo.csv')
# Out:
# Downloading AAIT
#   exchange                        shortName  \
# 0      PCX  iShares MSCI All Country Asia I
#
#                                   longName exchangeTimezoneName  \
# 0  iShares MSCI All Country Asia Info Tech     America/New_York
#
#   exchangeTimezoneShortName  isEsgPopulated gmtOffSetMilliseconds  \
# 0                       EST             0.0             -18000000
#
#   underlyingSymbol quoteType symbol  ... openInterest marketState marketCap  \
# 0             None       ETF   AAIT  ...         None     REGULAR      None
#
#   volumeAllCurrencies strikePrice preMarketSource maxAge  fromCurrency  \
# 0                None        None   FREE_REALTIME    1.0          None
#
#    regularMarketChangePercent  logo_url
# 0                    0.010476
#
# [1 rows x 50 columns]
# Downloading AAL
#   exchange                        shortName  \
# 0      PCX  iShares MSCI All Country Asia I
# 1      NMS    American Airlines Group, Inc.
#
#                                   longName exchangeTimezoneName  \
# 0  iShares MSCI All Country Asia Info Tech     America/New_York
# 1             American Airlines Group Inc.     America/New_York
#
#   exchangeTimezoneShortName isEsgPopulated gmtOffSetMilliseconds  \
# 0                       EST            0.0             -18000000
# 1                       EST           True             -18000000
#
#   underlyingSymbol quoteType symbol  ... tradeable trailingAnnualDividendRate  \
# 0             None       ETF   AAIT  ...       NaN                        NaN
# 1             None    EQUITY    AAL  ...       0.0                        0.0
#
#   trailingAnnualDividendYield trailingEps twoHundredDayAverage      volume  \
# 0                         NaN         NaN                  NaN         NaN
# 1                         0.0     -14.725             20.83105  21390063.0
#
#               website  yield  ytdReturn    zip
# 0                 NaN    NaN        NaN    NaN
# 1  https://www.aa.com   None       None  76155
#
# [2 rows x 167 columns]

# %%
df = stock_info.loc[stock_info['symbol'] == 'AAL']
df.sharesOutstanding
# Out:
# 1    641382976.0
# Name: sharesOutstanding, dtype: float64

# %%
yf.Ticker('GME').info
# Out:
# {'zip': '76051',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 12000,
#  'longBusinessSummary': 'GameStop Corp., a specialty retailer, provides games and entertainment products through its e-commerce properties and various stores in the United States, Canada, Australia, and Europe. The company sells new and pre-owned video game platforms; accessories, such as controllers, gaming headsets, virtual reality products, and memory cards; new and pre-owned video game software; and in-game digital currency, digital downloadable content, and full-game downloads, as well as network points cards, and prepaid digital and subscription cards. It also sells collectibles comprising licensed merchandise primarily related to the video game, television, and movie industries, as well as pop culture themes. The company operates its stores and e-commerce sites under the GameStop, EB Games, and Micromania brands; and collectibles stores under the Zing Pop Culture and ThinkGeek brand, as well as offers Game Informer, a print and digital video game publication featuring reviews of new title releases, game tips, and news regarding the video game industry. As of January 30, 2021, it operated 4,816 stores. The company was formerly known as GSC Holdings Corp. GameStop Corp. was founded in 1996 and is headquartered in Grapevine, Texas.',
#  'city': 'Grapevine',
#  'phone': '817 424 2000',
#  'state': 'TX',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.gamestop.com',
#  'maxAge': 1,
#  'address1': '625 Westport Parkway',
#  'industry': 'Specialty Retail',
#  'ebitdaMargins': -0.020179998,
#  'profitMargins': -0.02177,
#  'grossMargins': 0.24454,
#  'operatingCashflow': 154200000,
#  'revenueGrowth': 0.251,
#  'operatingMargins': -0.034760002,
#  'ebitda': -107900000,
#  'targetLowPrice': 25,
#  'recommendationKey': 'underperform',
#  'grossProfits': 1259500000,
#  'freeCashflow': -7125000,
#  'targetMedianPrice': 50,
#  'currentPrice': 152.75,
#  'earningsGrowth': None,
#  'currentRatio': 1.361,
#  'returnOnAssets': -0.04616,
#  'numberOfAnalystOpinions': 3,
#  'targetMeanPrice': 88.33,
#  'debtToEquity': 81.012,
#  'returnOnEquity': -0.17695,
#  'targetHighPrice': 190,
#  'totalCash': 694700032,
#  'totalDebt': 712499968,
#  'totalRevenue': 5345600000,
#  'totalCashPerShare': 10.037,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 81.768,
#  'quickRatio': 0.784,
#  'recommendationMean': 4,
#  'exchange': 'NYQ',
#  'shortName': 'GameStop Corporation',
#  'longName': 'GameStop Corp.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'underlyingSymbol': None,
#  'quoteType': 'EQUITY',
#  'symbol': 'GME',
#  'underlyingExchangeSymbol': None,
#  'headSymbol': None,
#  'messageBoardId': 'finmb_1342560',
#  'uuid': '8ded85bd-8171-3e2e-afa6-c81272285147',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.981,
#  'beta3Year': None,
#  'enterpriseToEbitda': -98.15,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': -0.53,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 70771800,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 6.688,
#  'sharesShort': 8075454,
#  'sharesPercentSharesOut': 0.1086,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1611964800,
#  'heldPercentInstitutions': 0.40814,
#  'netIncomeToCommon': -116300000,
#  'trailingEps': -3.312,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': 22.839413,
#  'heldPercentInsiders': 0.18974,
#  'nextFiscalYearEnd': 1675036800,
#  'yield': None,
#  'mostRecentQuarter': 1619827200,
#  'shortRatio': 1.89,
#  'sharesShortPreviousMonthDate': 1623715200,
#  'floatShares': 56411716,
#  'beta': -2.004352,
#  'enterpriseValue': 10590410752,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1174262400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': 2.0222974,
#  'dateShortInterest': 1626307200,
#  'pegRatio': 6.33,
#  'ytdReturn': None,
#  'forwardPE': -288.20755,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.18180001,
#  'sharesShortPriorMonth': 9670734,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 154,
#  'regularMarketOpen': 154,
#  'twoHundredDayAverage': 186.2171,
#  'trailingAnnualDividendYield': 0,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 154.65,
#  'navPrice': None,
#  'averageDailyVolume10Day': 1837220,
#  'regularMarketPreviousClose': 154,
#  'fiftyDayAverage': 183.5486,
#  'trailingAnnualDividendRate': 0,
#  'open': 154,
#  'averageVolume10days': 1837220,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1552521600,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 146.02,
#  'currency': 'USD',
#  'regularMarketVolume': 721221,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 10810392576,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 2336301,
#  'dayLow': 146.02,
#  'ask': 153.52,
#  'askSize': 1200,
#  'volume': 721221,
#  'fiftyTwoWeekHigh': 483,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 17.08,
#  'bid': 153.03,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 800,
#  'dayHigh': 154.65,
#  'regularMarketPrice': 152.75,
#  'logo_url': 'https://logo.clearbit.com/gamestop.com'}
