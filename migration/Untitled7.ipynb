# %%
from IPython.display import clear_output
from matplotlib import pyplot as plt
# %matplotlib inline
    
def live_plot(x, y, figsize=(7,5), title=''):
    training_steps=3
    clear_output(wait=True)
    plt.figure(figsize=figsize)
    plt.xlim(0, training_steps)
    plt.ylim(0, 100)
    x = [float(i) for i in x]
    y = [float(i) for i in y]
    
    if len(x) > 1:
        plt.scatter(x,y, label='axis y', color='k') 
        m, b = np.polyfit(x, y, 1)
        plt.plot(x, [x * m for x in x] + b)

    plt.title(title)
    plt.grid(True)
    plt.xlabel('axis x')
    plt.ylabel('axis y')
    plt.show()

# %%
live_plot(x=10,y=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9921/893359936.py in <module>
# ----> 1 live_plot(x=10,y=10)
#
# /tmp/ipykernel_9921/403669565.py in live_plot(x, y, figsize, title)
#       9     plt.xlim(0, training_steps)
#      10     plt.ylim(0, 100)
# ---> 11     x = [float(i) for i in x]
#      12     y = [float(i) for i in y]
#      13
#
# TypeError: 'int' object is not iterable

# %%
from IPython.display import clear_output
import numpy as np

for i in range(20):
    clear_output(wait=True)
    x = np.arange(1,100)
    y = x^2*3
    plt.plot(x, y, '-*r')
    plt.show()

# %%
for t in range(100):
   if t % refresh_rate == 0:

     plt.clf()
     plt.plot(history['val_loss'], 'r-', lw=2, label='val')
     plt.plot(history['training_loss'], 'b-', lw=1, label='training')
     plt.legend()
     display.clear_output(wait=True)
     display.display(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9921/3705655866.py in <module>
#       1 for t in range(100):
# ----> 2    if t % refresh_rate == 0:
#       3
#       4      plt.clf()
#       5      plt.plot(history['val_loss'], 'r-', lw=2, label='val')
#
# NameError: name 'refresh_rate' is not defined

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display
for i in range(10):
    pl.plot(pl.randn(100))
    display.clear_output(wait=True)
    display.display(pl.gcf())
    time.sleep(1.0)
