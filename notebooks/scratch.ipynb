# %%
import os
'''
    For the given path, get the List of all files in the directory tree 
'''
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
path ='shortdata'
exch ='CNMS'
findme = os.path.join(path,exch)
derp = getListOfFiles(findme)

# %%
for file in derp:
    working = open(file,'r')
    Lines = working.readlines()
    count = 0 
    for line in Lines:
        count += 1
        if count < 3:
            print(line)
    print(line)
    print("file: {} total lines {}".format(working.name, count))
# Out:
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220111|A|312846|481|729203|B,Q,N
#
# 10164
#
# file: shortdata/CNMS/CNMSshvol20220111.txt total lines 10166
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211216|A|123010|9812|380834|B,Q,N
#
# 10191
#
# file: shortdata/CNMS/CNMSshvol20211216.txt total lines 10193
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220104|A|144865|50|559320|B,Q,N
#
# 10168
#
# file: shortdata/CNMS/CNMSshvol20220104.txt total lines 10170
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211207|A|150740|7|295109|B,Q,N
#
# 10238
#
# file: shortdata/CNMS/CNMSshvol20211207.txt total lines 10240
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200102|A|93998|378|277507|B,Q,N
#
# 8172
#
# file: shortdata/CNMS/CNMSshvol20200102.txt total lines 8174
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211228|A|58134|104|156946|B,Q,N
#
# 10214
#
# file: shortdata/CNMS/CNMSshvol20211228.txt total lines 10216
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211223|A|107776|27|392248|B,Q,N
#
# 10181
#
# file: shortdata/CNMS/CNMSshvol20211223.txt total lines 10183
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200106|A|140749|952|425920|B,Q,N
#
# 8075
#
# file: shortdata/CNMS/CNMSshvol20200106.txt total lines 8077
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211214|A|165802|12|391882|B,Q,N
#
# 10207
#
# file: shortdata/CNMS/CNMSshvol20211214.txt total lines 10209
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211220|A|135835|2863|589349|B,Q,N
#
# 10253
#
# file: shortdata/CNMS/CNMSshvol20211220.txt total lines 10255
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220103|A|114330|102|402324|B,Q,N
#
# 10351
#
# file: shortdata/CNMS/CNMSshvol20220103.txt total lines 10353
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211209|A|67555|8|185870|B,Q,N
#
# 10206
#
# file: shortdata/CNMS/CNMSshvol20211209.txt total lines 10208
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200107|A|66774|30|413558|B,Q,N
#
# 8049
#
# file: shortdata/CNMS/CNMSshvol20200107.txt total lines 8051
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200103|A|88944|74|266653|B,Q,N
#
# 8124
#
# file: shortdata/CNMS/CNMSshvol20200103.txt total lines 8126
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220112|A|225641|0|437656|B,Q,N
#
# 10154
#
# file: shortdata/CNMS/CNMSshvol20220112.txt total lines 10156
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220110|A|184448|1096|584900|B,Q,N
#
# 10264
#
# file: shortdata/CNMS/CNMSshvol20220110.txt total lines 10266
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211203|A|108474|113|229822|B,Q,N
#
# 10240
#
# file: shortdata/CNMS/CNMSshvol20211203.txt total lines 10242
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211222|A|279627|716|537545|B,Q,N
#
# 10153
#
# file: shortdata/CNMS/CNMSshvol20211222.txt total lines 10155
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211202|A|146399|0|318733|B,Q,N
#
# 10156
#
# file: shortdata/CNMS/CNMSshvol20211202.txt total lines 10158
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211206|A|203195|345|445824|B,Q,N
#
# 10257
#
# file: shortdata/CNMS/CNMSshvol20211206.txt total lines 10259
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211213|A|93395|200|254899|B,Q,N
#
# 10182
#
# file: shortdata/CNMS/CNMSshvol20211213.txt total lines 10184
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211221|A|165401|0|316919|B,Q,N
#
# 10202
#
# file: shortdata/CNMS/CNMSshvol20211221.txt total lines 10204
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211229|A|57634|78|163543|B,Q,N
#
# 10257
#
# file: shortdata/CNMS/CNMSshvol20211229.txt total lines 10259
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211231|A|114489|10|230981|B,Q,N
#
# 10261
#
# file: shortdata/CNMS/CNMSshvol20211231.txt total lines 10263
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211210|A|128683|33|334471|B,Q,N
#
# 10183
#
# file: shortdata/CNMS/CNMSshvol20211210.txt total lines 10185
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220107|A|143795|1787|666764|B,Q,N
#
# 10168
#
# file: shortdata/CNMS/CNMSshvol20220107.txt total lines 10170
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211230|A|40967|35|110656|B,Q,N
#
# 10253
#
# file: shortdata/CNMS/CNMSshvol20211230.txt total lines 10255
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220106|A|265366|105|663846|B,Q,N
#
# 10197
#
# file: shortdata/CNMS/CNMSshvol20220106.txt total lines 10199
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220105|A|162657|536|385891|B,Q,N
#
# 10222
#
# file: shortdata/CNMS/CNMSshvol20220105.txt total lines 10224
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211215|A|123301|240|372006|B,Q,N
#
# 10280
#
# file: shortdata/CNMS/CNMSshvol20211215.txt total lines 10282
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211201|A|132251|122|337353|B,Q,N
#
# 10325
#
# file: shortdata/CNMS/CNMSshvol20211201.txt total lines 10327
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20220113|A|183829|0|394983|B,Q,N
#
# 10092
#
# file: shortdata/CNMS/CNMSshvol20220113.txt total lines 10094
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211227|A|82118|36|152224|B,Q,N
#
# 10271
#
# file: shortdata/CNMS/CNMSshvol20211227.txt total lines 10273
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211217|A|122569|151|410642|B,Q,N
#
# 10183
#
# file: shortdata/CNMS/CNMSshvol20211217.txt total lines 10185
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200108|A|155459|1318|452131|B,Q,N
#
# 8069
#
# file: shortdata/CNMS/CNMSshvol20200108.txt total lines 8071
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20200109|A|199843|369|418630|B,Q,N
#
# 8034
#
# file: shortdata/CNMS/CNMSshvol20200109.txt total lines 8036
# Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
#
# 20211208|A|61325|125|186573|B,Q,N
#
# 10100
#
# file: shortdata/CNMS/CNMSshvol20211208.txt total lines 10102

# %%
workingwerawe
# Out:
# <_io.TextIOWrapper name='shortdata/CNMS/CNMSshvol20211208.txt' mode='r' encoding='UTF-8'>

# %%
# Using readlines()

file1 = open('myfile.txt', 'r')
Lines = file1.readlines()
 
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))

# %%
import pandas as pd
# create empty list
dataframes_list = []

    
for file in derp:
    working = open(file,'r')
    temp_df = pd.read_csv(file, delimiter='|',)
    temp_df = temp_df.dropna()
    dataframes_list.append(temp_df)
df = pd.concat(dataframes_list)

# %%
df
# Out:
#            Date Symbol  ShortVolume  ShortExemptVolume  TotalVolume Market
# 0      20220111      A     312846.0              481.0     729203.0  B,Q,N
# 1      20220111     AA     684218.0             1279.0    2064270.0  B,Q,N
# 2      20220111    AAA        100.0                0.0        102.0      Q
# 3      20220111   AAAU      33159.0                0.0      96148.0  B,Q,N
# 4      20220111    AAC        124.0                0.0       2656.0    Q,N
# ...         ...    ...          ...                ...          ...    ...
# 10095  20211208    ZWS      32489.0                0.0     105211.0  B,Q,N
# 10096  20211208     ZY      65131.0             6577.0     245831.0  B,Q,N
# 10097  20211208   ZYME     620897.0              100.0     790290.0  B,Q,N
# 10098  20211208   ZYNE      84441.0                0.0     192802.0  B,Q,N
# 10099  20211208   ZYXI       5780.0                0.0      27505.0  B,Q,N
#
# [365096 rows x 6 columns]

# %%
df_from_each_file = (pd.read_csv(f) for f in derp)
concatenated_df   = pd.concat(df_from_each_file)

# %%
concatenated_df.tail()
# Out:
#                                       Date|Symbol|ShortVolume|ShortExemptVolume|TotalVolume|Market
# 20211208|ZY|65131|6577|245831|B   Q                                                    N
# 20211208|ZYME|620897|100|790290|B Q                                                    N
# 20211208|ZYNE|84441|0|192802|B    Q                                                    N
# 20211208|ZYXI|5780|0|27505|B      Q                                                    N
# 10100                             NaN                                                NaN

# %%
def f(i):
    return pd.read_csv(i, header=None)

df = pd.concat(map(f, filepaths))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13042/2939722040.py in <module>
#       2     return pd.read_csv(i, header=None)
#       3
# ----> 4 df = pd.concat(map(f, filepaths))
#
# NameError: name 'filepaths' is not defined

# %%
# import module
import pandas as pd
 
# assign dataset names
list_of_names = ['crime','username']
 
# create empty list
dataframes_list = []
 
# append datasets into teh list
for i in range(len(list_of_names)):
    temp_df = pd.read_csv("./csv/"+list_of_names[i]+".csv")
    dataframes_list.append(temp_df)
