# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import fnmatch
import datetime

import os
import pandas as pd

# %%
dd ='20210729'
cnms = 'CNMSshvol'+dd+'.txt'
bdir =  '/mnt/5c823cd2-502b-4990-a220-579838be1f10/data/shortdata2/'

# %%
f = bdir +cnms
df = pd.read_csv(f,sep="|")

df
# Out:
#           Date Symbol  ShortVolume  ShortExemptVolume  TotalVolume Market
# 0     20210729      A     122613.0                0.0     381910.0  B,Q,N
# 1     20210729     AA    1012351.0            14047.0    2650695.0  B,Q,N
# 2     20210729    AAA        400.0                0.0        400.0      Q
# 3     20210729   AAAU      22241.0                0.0      56357.0    Q,N
# 4     20210729    AAC       3678.0                0.0      56052.0  B,Q,N
# ...        ...    ...          ...                ...          ...    ...
# 9791  20210729     ZY      27420.0                0.0      37812.0  B,Q,N
# 9792  20210729   ZYME      34060.0             3321.0      84903.0  B,Q,N
# 9793  20210729   ZYNE      34281.0               64.0     112554.0  B,Q,N
# 9794  20210729   ZYXI      16467.0              363.0      41584.0  B,Q,N
# 9795      9795    NaN          NaN                NaN          NaN    NaN
#
# [9796 rows x 6 columns]

# %%
sv = df['ShortVolume']
tv = df['TotalVolume']
df2 =df
df2['PercentShort']=sv/tv*100
df2 = df2.dropna()
df2
# Out:
#           Date Symbol  ShortVolume  ShortExemptVolume  TotalVolume Market  \
# 0     20210729      A     122613.0                0.0     381910.0  B,Q,N
# 1     20210729     AA    1012351.0            14047.0    2650695.0  B,Q,N
# 2     20210729    AAA        400.0                0.0        400.0      Q
# 3     20210729   AAAU      22241.0                0.0      56357.0    Q,N
# 4     20210729    AAC       3678.0                0.0      56052.0  B,Q,N
# ...        ...    ...          ...                ...          ...    ...
# 9790  20210729  ZWRKW      22300.0                0.0      22300.0    B,Q
# 9791  20210729     ZY      27420.0                0.0      37812.0  B,Q,N
# 9792  20210729   ZYME      34060.0             3321.0      84903.0  B,Q,N
# 9793  20210729   ZYNE      34281.0               64.0     112554.0  B,Q,N
# 9794  20210729   ZYXI      16467.0              363.0      41584.0  B,Q,N
#
#       PercentShort
# 0        32.105208
# 1        38.191908
# 2       100.000000
# 3        39.464485
# 4         6.561764
# ...            ...
# 9790    100.000000
# 9791     72.516661
# 9792     40.116368
# 9793     30.457380
# 9794     39.599365
#
# [9795 rows x 7 columns]

# %%
GME = df2[df2['Symbol']==('GME')]

# %%
plt.figure(figsize=(15,5))
per = df2['PercentShort']
n, bins, patches = plt.hist(per, bins=100);
xx = int(GME['PercentShort'])
nn = n[xx]
patches[xx].set_fc('r')

# Add annotation
plt.annotate('GME', xy=(xx, nn), xytext=(xx+10, nn+20), 
             fontsize=15, arrowprops={'width':0.4,'headwidth':7,'color':'#333333'})
plt.ylabel('Number of Tickers Per Bin')
plt.xlabel('Percent Short aka Bin')
plt.title('Histogram Short Percentages for the Day {} across market'.format(dd))
# Out:
# Text(0.5, 1.0, 'Histogram Short Percentages for the Day 20210729 across market')

# %%
n[50]
# Out:
# 138.0

# %%
plt.figure(figsize=(15,5))
plt.plot(per)

# %%
mask = df['PercentShort']>70
