# %%
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io

# %%
start = datetime.datetime(2020,2,1)
end = datetime.datetime(2020,10,11)

# %%
url="https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed_csv/data/7665719fb51081ba0bd834fde71ce822/nasdaq-listed_csv.csv"
s = requests.get(url).content
companies = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
Symbols = companies['Symbol'].tolist()

# %%
# create empty dataframe
stock_final = pd.DataFrame()# iterate over each symbol
for i in Symbols:  
    
    # print the symbol which is being downloaded
    print( str(Symbols.index(i)) + str(' : ') + i, sep=',', end=',', flush=True)  
    
    try:
        # download the stock price 
        stock = []
        stock = yf.download(i,start=start, end=end, progress=False)
        
        # append the individual stock prices 
        if len(stock) == 0:
            None
        else:
            stock['Name']=i
            stock_final = stock_final.append(stock,sort=False)
    except Exception:
        None
# Out:
# 0 : AAIT,1 : AAL,2 : AAME,3 : AAOI,4 : AAON,5 : AAPL,6 : AAVL,
# 1 Failed download:
# - AAVL: No data found for this date range, symbol may be delisted
# 7 : AAWW,8 : AAXJ,9 : ABAC,
# 1 Failed download:
# - ABAC: No data found for this date range, symbol may be delisted
# 10 : ABAX,
# 1 Failed download:
# - ABAX: No data found for this date range, symbol may be delisted
# 11 : ABCB,12 : ABCD,
# 1 Failed download:
# - ABCD: No data found for this date range, symbol may be delisted
# 13 : ABCO,14 : ABCW,
# 1 Failed download:
# - ABCW: No data found for this date range, symbol may be delisted
# 15 : ABDC,
# 1 Failed download:
# - ABDC: No data found, symbol may be delisted
# 16 : ABGB,
# 1 Failed download:
# - ABGB: No data found for this date range, symbol may be delisted
# 17 : ABIO,18 : ABMD,19 : ABTL,
# 1 Failed download:
# - ABTL: No data found for this date range, symbol may be delisted
# 20 : ABY,
# 1 Failed download:
# - ABY: No data found for this date range, symbol may be delisted
# 21 : ACAD,22 : ACAS,
# 1 Failed download:
# - ACAS: No data found for this date range, symbol may be delisted
# 23 : ACAT,
# 1 Failed download:
# - ACAT: No data found for this date range, symbol may be delisted
# 24 : ACET,25 : ACFC,
# 1 Failed download:
# - ACFC: No data found for this date range, symbol may be delisted
# 26 : ACFN,27 : ACGL,28 : ACHC,29 : ACHN,
# 1 Failed download:
# - ACHN: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 30 : ACIW,31 : ACLS,32 : ACNB,33 : ACOR,34 : ACPW,
# 1 Failed download:
# - ACPW: No data found for this date range, symbol may be delisted
# 35 : ACRX,36 : ACSF,
# 1 Failed download:
# - ACSF: No data found, symbol may be delisted
# 37 : ACST,38 : ACTA,
# 1 Failed download:
# - ACTA: No data found for this date range, symbol may be delisted
# 39 : ACTG,40 : ACTS,
# 1 Failed download:
# - ACTS: No data found for this date range, symbol may be delisted
# 41 : ACUR,42 : ACWI,43 : ACWX,44 : ACXM,
# 1 Failed download:
# - ACXM: No data found for this date range, symbol may be delisted
# 45 : ADAT,
# 1 Failed download:
# - ADAT: No data found for this date range, symbol may be delisted
# 46 : ADBE,47 : ADEP,
# 1 Failed download:
# - ADEP: No data found for this date range, symbol may be delisted
# 48 : ADES,49 : ADHD,
# 1 Failed download:
# - ADHD: No data found for this date range, symbol may be delisted
# 50 : ADI,51 : ADMA,52 : ADMP,53 : ADMS,54 : ADNC,
# 1 Failed download:
# - ADNC: No data found for this date range, symbol may be delisted
# 55 : ADP,56 : ADRA,
# 1 Failed download:
# - ADRA: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 57 : ADRD,58 : ADRE,59 : ADRU,60 : ADSK,61 : ADTN,62 : ADUS,63 : ADVS,
# 1 Failed download:
# - ADVS: No data found for this date range, symbol may be delisted
# 64 : ADXS,65 : ADXSW,
# 1 Failed download:
# - ADXSW: No data found, symbol may be delisted
# 66 : AEGN,
# 1 Failed download:
# - AEGN: No data found, symbol may be delisted
# 67 : AEGR,
# 1 Failed download:
# - AEGR: No data found for this date range, symbol may be delisted
# 68 : AEHR,69 : AEIS,70 : AEPI,
# 1 Failed download:
# - AEPI: No data found for this date range, symbol may be delisted
# 71 : AERI,72 : AETI,
# 1 Failed download:
# - AETI: No data found, symbol may be delisted
# 73 : AEY,74 : AEZS,75 : AFAM,
# 1 Failed download:
# - AFAM: No data found for this date range, symbol may be delisted
# 76 : AFCB,
# 1 Failed download:
# - AFCB: No data found for this date range, symbol may be delisted
# 77 : AFFX,
# 1 Failed download:
# - AFFX: No data found for this date range, symbol may be delisted
# 78 : AFH,
# 1 Failed download:
# - AFH: No data found, symbol may be delisted
# 79 : AFMD,80 : AFOP,
# 1 Failed download:
# - AFOP: No data found for this date range, symbol may be delisted
# 81 : AFSI,
# 1 Failed download:
# - AFSI: No data found for this date range, symbol may be delisted
# 82 : AGEN,83 : AGII,
# 1 Failed download:
# - AGII: No data found for this date range, symbol may be delisted
# 84 : AGIIL,
# 1 Failed download:
# - AGIIL: No data found, symbol may be delisted
# 85 : AGIO,86 : AGNC,87 : AGNCB,
# 1 Failed download:
# - AGNCB: No data found, symbol may be delisted
# 88 : AGNCP,89 : AGND,90 : AGRX,91 : AGTC,92 : AGYS,93 : AGZD,94 : AHGP,
# 1 Failed download:
# - AHGP: No data found for this date range, symbol may be delisted
# 95 : AHPI,96 : AIMC,97 : AINV,98 : AIQ,99 : AIRM,
# 1 Failed download:
# - AIRM: No data found for this date range, symbol may be delisted
# 100 : AIRR,101 : AIRT,102 : AIXG,
# 1 Failed download:
# - AIXG: No data found for this date range, symbol may be delisted
# 103 : AKAM,104 : AKAO,
# 1 Failed download:
# - AKAO: No data found, symbol may be delisted
# 105 : AKBA,106 : AKER,
# 1 Failed download:
# - AKER: No data found, symbol may be delisted
# 107 : AKRX,
# 1 Failed download:
# - AKRX: No data found, symbol may be delisted
# 108 : ALCO,109 : ALDR,
# 1 Failed download:
# - ALDR: No data found, symbol may be delisted
# 110 : ALDX,111 : ALGN,112 : ALGT,113 : ALIM,114 : ALKS,115 : ALLB,
# 1 Failed download:
# - ALLB: No data found for this date range, symbol may be delisted
# 116 : ALLT,117 : ALNY,118 : ALOG,
# 1 Failed download:
# - ALOG: No data found for this date range, symbol may be delisted
# 119 : ALOT,120 : ALQA,
# 1 Failed download:
# - ALQA: No data found, symbol may be delisted
# 121 : ALSK,
# 1 Failed download:
# - ALSK: No data found, symbol may be delisted
# 122 : ALTR,123 : ALXA,
# 1 Failed download:
# - ALXA: No data found for this date range, symbol may be delisted
# 124 : ALXN,
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
# 125 : AMAG,
# 1 Failed download:
# - AMAG: No data found, symbol may be delisted
# 126 : AMAT,127 : AMBA,128 : AMBC,129 : AMBCW,
# 1 Failed download:
# - AMBCW: No data found, symbol may be delisted
# 130 : AMCC,
# 1 Failed download:
# - AMCC: No data found for this date range, symbol may be delisted
# 131 : AMCF,132 : AMCN,
# 1 Failed download:
# - AMCN: No data found, symbol may be delisted
# 133 : AMCX,134 : AMD,135 : AMDA,
# 1 Failed download:
# - AMDA: No data found for this date range, symbol may be delisted
# 136 : AMED,137 : AMGN,138 : AMIC,
# 1 Failed download:
# - AMIC: No data found for this date range, symbol may be delisted
# 139 : AMKR,140 : AMNB,141 : AMOT,142 : AMOV,143 : AMPH,144 : AMRB,
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
# 145 : AMRI,
# 1 Failed download:
# - AMRI: No data found for this date range, symbol may be delisted
# 146 : AMRK,147 : AMRN,148 : AMRS,149 : AMSC,150 : AMSF,151 : AMSG,
# 1 Failed download:
# - AMSG: No data found for this date range, symbol may be delisted
# 152 : AMSGP,
# 1 Failed download:
# - AMSGP: No data found, symbol may be delisted
# 153 : AMSWA,154 : AMTX,155 : AMWD,156 : AMZN,157 : ANAC,
# 1 Failed download:
# - ANAC: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 158 : ANAD,
# 1 Failed download:
# - ANAD: No data found for this date range, symbol may be delisted
# 159 : ANAT,160 : ANCB,
# 1 Failed download:
# - ANCB: No data found for this date range, symbol may be delisted
# 161 : ANCI,
# 1 Failed download:
# - ANCI: No data found for this date range, symbol may be delisted
# 162 : ANCX,
# 1 Failed download:
# - ANCX: No data found for this date range, symbol may be delisted
# 163 : ANDE,164 : ANGI,165 : ANGO,166 : ANIK,167 : ANIP,168 : ANSS,169 : ANTH,170 : ANY,171 : AOSL,172 : APAGF,
# 1 Failed download:
# - APAGF: No data found for this date range, symbol may be delisted
# 173 : APDN,174 : APDNW,
# 1 Failed download:
# - APDNW: No data found, symbol may be delisted
# 175 : APEI,176 : APOG,177 : APOL,
# 1 Failed download:
# - APOL: No data found for this date range, symbol may be delisted
# 178 : APPY,
# 1 Failed download:
# - APPY: No data found for this date range, symbol may be delisted
# 179 : APRI,
# 1 Failed download:
# - APRI: No data found for this date range, symbol may be delisted
# 180 : APSA,
# 1 Failed download:
# - APSA: No data found for this date range, symbol may be delisted
# 181 : APTO,182 : APWC,183 : AQXP,
# 1 Failed download:
# - AQXP: No data found, symbol may be delisted
# 184 : ARAY,185 : ARCB,186 : ARCC,187 : ARCI,
# 1 Failed download:
# - ARCI: No data found, symbol may be delisted
# 188 : ARCP,
# 1 Failed download:
# - ARCP: No data found for this date range, symbol may be delisted
# 189 : ARCPP,
# 1 Failed download:
# - ARCPP: No data found, symbol may be delisted
# 190 : ARCW,191 : ARDM,
# 1 Failed download:
# - ARDM: No data found, symbol may be delisted
# 192 : ARDX,193 : AREX,
# 1 Failed download:
# - AREX: No data found, symbol may be delisted
# 194 : ARGS,
# 1 Failed download:
# - ARGS: No data found for this date range, symbol may be delisted
# 195 : ARIA,
# 1 Failed download:
# - ARIA: No data found for this date range, symbol may be delisted
# 196 : ARII,
# 1 Failed download:
# - ARII: No data found for this date range, symbol may be delisted
# 197 : ARIS,
# 1 Failed download:
# - ARIS: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 198 : ARKR,199 : ARLP,200 : ARMH,
# 1 Failed download:
# - ARMH: No data found for this date range, symbol may be delisted
# 201 : ARNA,202 : AROW,203 : ARQL,
# 1 Failed download:
# - ARQL: No data found, symbol may be delisted
# 204 : ARRS,
# 1 Failed download:
# - ARRS: No data found, symbol may be delisted
# 205 : ARRY,
# 1 Failed download:
# - ARRY: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 206 : ARTNA,207 : ARTW,208 : ARTX,
# 1 Failed download:
# - ARTX: No data found, symbol may be delisted
# 209 : ARUN,
# 1 Failed download:
# - ARUN: No data found for this date range, symbol may be delisted
# 210 : ARWR,211 : ASBB,
# 1 Failed download:
# - ASBB: No data found for this date range, symbol may be delisted
# 212 : ASBI,
# 1 Failed download:
# - ASBI: No data found for this date range, symbol may be delisted
# 213 : ASCMA,
# 1 Failed download:
# - ASCMA: No data found, symbol may be delisted
# 214 : ASEI,
# 1 Failed download:
# - ASEI: No data found for this date range, symbol may be delisted
# 215 : ASFI,
# 1 Failed download:
# - ASFI: No data found, symbol may be delisted
# 216 : ASMB,217 : ASMI,
# 1 Failed download:
# - ASMI: No data found for this date range, symbol may be delisted
# 218 : ASML,219 : ASNA,
# 1 Failed download:
# - ASNA: No data found, symbol may be delisted
# 220 : ASPS,221 : ASPX,
# 1 Failed download:
# - ASPX: No data found for this date range, symbol may be delisted
# 222 : ASRV,223 : ASRVP,
# 1 Failed download:
# - ASRVP: No data found, symbol may be delisted
# 224 : ASTC,225 : ASTE,226 : ASTI,227 : ASUR,228 : ASYS,229 : ATAI,
# 1 Failed download:
# - ATAI: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 230 : ATAX,231 : ATEA,
# 1 Failed download:
# - ATEA: No data found, symbol may be delisted
# 232 : ATEC,233 : ATHN,
# 1 Failed download:
# - ATHN: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 234 : ATHX,235 : ATLC,236 : ATLO,237 : ATML,
# 1 Failed download:
# - ATML: No data found for this date range, symbol may be delisted
# 238 : ATNI,239 : ATNY,
# 1 Failed download:
# - ATNY: No data found for this date range, symbol may be delisted
# 240 : ATOS,241 : ATRA,242 : ATRC,243 : ATRI,244 : ATRM,
# 1 Failed download:
# - ATRM: No data found, symbol may be delisted
# 245 : ATRO,246 : ATRS,247 : ATSG,248 : ATTU,
# 1 Failed download:
# - ATTU: No data found, symbol may be delisted
# 249 : ATVI,250 : AUBN,251 : AUDC,252 : AUMA,
# 1 Failed download:
# - AUMA: No data found for this date range, symbol may be delisted
# 253 : AUMAU,
# 1 Failed download:
# - AUMAU: No data found for this date range, symbol may be delisted
# 254 : AUMAW,
# 1 Failed download:
# - AUMAW: No data found, symbol may be delisted
# 255 : AUPH,256 : AUXL,
# 1 Failed download:
# - AUXL: No data found for this date range, symbol may be delisted
# 257 : AVAV,258 : AVEO,259 : AVGO,260 : AVHI,
# 1 Failed download:
# - AVHI: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 261 : AVID,262 : AVNR,
# 1 Failed download:
# - AVNR: No data found for this date range, symbol may be delisted
# 263 : AVNW,264 : AWAY,265 : AWRE,266 : AXAS,267 : AXDX,268 : AXGN,269 : AXJS,
# 1 Failed download:
# - AXJS: No data found for this date range, symbol may be delisted
# 270 : AXPW,
# 1 Failed download:
# - AXPW: No data found for this date range, symbol may be delisted
# 271 : AXPWW,
# 1 Failed download:
# - AXPWW: No data found, symbol may be delisted
# 272 : AXTI,273 : AZPN,274 : BABY,
# 1 Failed download:
# - BABY: No data found, symbol may be delisted
# 275 : BAGR,
# 1 Failed download:
# - BAGR: No data found for this date range, symbol may be delisted
# 276 : BAMM,
# 1 Failed download:
# - BAMM: No data found for this date range, symbol may be delisted
# 277 : BANF,278 : BANFP,279 : BANR,280 : BANX,281 : BASI,
# 1 Failed download:
# - BASI: No data found, symbol may be delisted
# 282 : BBBY,283 : BBC,284 : BBCN,
# 1 Failed download:
# - BBCN: No data found for this date range, symbol may be delisted
# 285 : BBEP,
# 1 Failed download:
# - BBEP: No data found for this date range, symbol may be delisted
# 286 : BBEPP,
# 1 Failed download:
# - BBEPP: No data found, symbol may be delisted
# 287 : BBGI,288 : BBLU,
# 1 Failed download:
# - BBLU: No data found for this date range, symbol may be delisted
# 289 : BBNK,
# 1 Failed download:
# - BBNK: No data found for this date range, symbol may be delisted
# 290 : BBOX,
# 1 Failed download:
# - BBOX: No data found for this date range, symbol may be delisted
# 291 : BBP,292 : BBRG,
# 1 Failed download:
# - BBRG: No data found for this date range, symbol may be delisted
# 293 : BBRY,
# 1 Failed download:
# - BBRY: No data found for this date range, symbol may be delisted
# 294 : BBSI,295 : BCBP,296 : BCLI,297 : BCOM,
# 1 Failed download:
# - BCOM: No data found, symbol may be delisted
# 298 : BCOR,299 : BCOV,300 : BCPC,301 : BCRX,302 : BDBD,
# 1 Failed download:
# - BDBD: No data found for this date range, symbol may be delisted
# 303 : BDCV,
# 1 Failed download:
# - BDCV: No data found, symbol may be delisted
# 304 : BDE,
# 1 Failed download:
# - BDE: No data found for this date range, symbol may be delisted
# 305 : BDGE,
# 1 Failed download:
# - BDGE: No data found, symbol may be delisted
# 306 : BDMS,
# 1 Failed download:
# - BDMS: No data found for this date range, symbol may be delisted
# 307 : BDSI,308 : BEAT,
# 1 Failed download:
# - BEAT: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 309 : BEAV,
# 1 Failed download:
# - BEAV: No data found for this date range, symbol may be delisted
# 310 : BEBE,311 : BECN,312 : BELFA,313 : BELFB,314 : BFIN,315 : BGCP,316 : BGFV,317 : BGMD,318 : BHBK,
# 1 Failed download:
# - BHBK: No data found, symbol may be delisted
# 319 : BIB,320 : BICK,321 : BIDU,322 : BIIB,323 : BIND,
# 1 Failed download:
# - BIND: None
# 324 : BIOC,325 : BIOD,
# 1 Failed download:
# - BIOD: None
# 326 : BIOL,327 : BIOS,
# 1 Failed download:
# - BIOS: No data found, symbol may be delisted
# 328 : BIRT,
# 1 Failed download:
# - BIRT: None
# 329 : BIS,330 : BJRI,331 : BKCC,332 : BKEP,333 : BKEPP,334 : BKMU,
# 1 Failed download:
# - BKMU: None
# 335 : BKSC,336 : BKYF,
# 1 Failed download:
# - BKYF: None
# 337 : BLCM,338 : BLDP,339 : BLDR,340 : BLFS,341 : BLIN,342 : BLKB,343 : BLMN,344 : BLMT,
# 1 Failed download:
# - BLMT: No data found, symbol may be delisted
# 345 : BLRX,346 : BLUE,347 : BLVD,
# 1 Failed download:
# - BLVD: None
# 348 : BLVDU,
# 1 Failed download:
# - BLVDU: None
# 349 : BLVDW,
# 1 Failed download:
# - BLVDW: No data found, symbol may be delisted
# 350 : BMRC,351 : BMRN,352 : BMTC,353 : BNCL,
# 1 Failed download:
# - BNCL: No data found, symbol may be delisted
# 354 : BNCN,
# 1 Failed download:
# - BNCN: None
# 355 : BNDX,356 : BNFT,357 : BNSO,358 : BOBE,
# 1 Failed download:
# - BOBE: None
# 359 : BOCH,
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
# 360 : BOFI,
# 1 Failed download:
# - BOFI: None
# 361 : BOKF,362 : BONA,
# 1 Failed download:
# - BONA: None
# 363 : BONT,
# 1 Failed download:
# - BONT: None
# 364 : BOOM,365 : BOSC,366 : BOTA,
# 1 Failed download:
# - BOTA: None
# 367 : BOTJ,368 : BPFH,
# 1 Failed download:
# - BPFH: No data found, symbol may be delisted
# 369 : BPFHP,
# 1 Failed download:
# - BPFHP: No data found, symbol may be delisted
# 370 : BPFHW,
# 1 Failed download:
# - BPFHW: No data found, symbol may be delisted
# 371 : BPOP,372 : BPOPM,373 : BPOPN,374 : BPTH,375 : BRCD,
# 1 Failed download:
# - BRCD: None
# 376 : BRCM,
# 1 Failed download:
# - BRCM: None
# 377 : BRDR,
# 1 Failed download:
# - BRDR: No data found, symbol may be delisted
# 378 : BREW,
# 1 Failed download:
# - BREW: No data found, symbol may be delisted
# 379 : BRID,380 : BRKL,381 : BRKR,382 : BRKS,383 : BRLI,384 : BSDM,
# 1 Failed download:
# - BSDM: None
# 385 : BSET,386 : BSF,
# 1 Failed download:
# - BSF: No data found for this date range, symbol may be delisted
# 387 : BSFT,
# 1 Failed download:
# - BSFT: None
# 388 : BSPM,389 : BSQR,390 : BSRR,391 : BSTC,
# 1 Failed download:
# - BSTC: No data found, symbol may be delisted
# 392 : BTUI,
# 1 Failed download:
# - BTUI: None
# 393 : BUR,
# 1 Failed download:
# - BUR: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 394 : BUSE,395 : BV,396 : BVA,
# 1 Failed download:
# - BVA: None
# 397 : BVSN,
# 1 Failed download:
# - BVSN: No data found, symbol may be delisted
# 398 : BWEN,399 : BWFG,400 : BWINA,
# 1 Failed download:
# - BWINA: None
# 401 : BWINB,
# 1 Failed download:
# - BWINB: None
# 402 : BWLD,
# 1 Failed download:
# - BWLD: None
# 403 : BYBK,
# 1 Failed download:
# - BYBK: No data found for this date range, symbol may be delisted
# 404 : BYFC,405 : BYLK,
# 1 Failed download:
# - BYLK: None
# 406 : CA,
# 1 Failed download:
# - CA: No data found for this date range, symbol may be delisted
# 407 : CAAS,408 : CAC,409 : CACB,
# 1 Failed download:
# - CACB: None
# 410 : CACC,411 : CACG,412 : CACGU,
# 1 Failed download:
# - CACGU: None
# 413 : CACGW,
# 1 Failed download:
# - CACGW: No data found, symbol may be delisted
# 414 : CACH,415 : CACQ,
# 1 Failed download:
# - CACQ: None
# 416 : CADC,
# 1 Failed download:
# - CADC: No data found, symbol may be delisted
# 417 : CADT,
# 1 Failed download:
# - CADT: None
# 418 : CADTR,
# 1 Failed download:
# - CADTR: No data found, symbol may be delisted
# 419 : CADTU,
# 1 Failed download:
# - CADTU: None
# 420 : CADTW,
# 1 Failed download:
# - CADTW: No data found, symbol may be delisted
# 421 : CAKE,422 : CALA,423 : CALD,
# 1 Failed download:
# - CALD: No data found for this date range, symbol may be delisted
# 424 : CALI,425 : CALL,426 : CALM,427 : CAMB,
# 1 Failed download:
# - CAMB: No data found, symbol may be delisted
# 428 : CAMBU,
# 1 Failed download:
# - CAMBU: No data found, symbol may be delisted
# 429 : CAMBW,
# 1 Failed download:
# - CAMBW: No data found, symbol may be delisted
# 430 : CAMP,431 : CAMT,432 : CAPN,
# 1 Failed download:
# - CAPN: None
# 433 : CAPNW,
# 1 Failed download:
# - CAPNW: No data found, symbol may be delisted
# 434 : CAR,435 : CARA,436 : CARB,
# 1 Failed download:
# - CARB: No data found, symbol may be delisted
# 437 : CARO,
# 1 Failed download:
# - CARO: No data found, symbol may be delisted
# 438 : CART,
# 1 Failed download:
# - CART: No data found, symbol may be delisted
# 439 : CARV,440 : CARZ,441 : CASH,442 : CASI,443 : CASM,
# 1 Failed download:
# - CASM: No data found, symbol may be delisted
# 444 : CASS,445 : CASY,446 : CATM,
# 1 Failed download:
# - CATM: No data found, symbol may be delisted
# 447 : CATY,448 : CATYW,
# 1 Failed download:
# - CATYW: No data found, symbol may be delisted
# 449 : CAVM,
# 1 Failed download:
# - CAVM: No data found for this date range, symbol may be delisted
# 450 : CBAK,
# 1 Failed download:
# - CBAK: None
# 451 : CBAN,452 : CBAY,453 : CBDE,
# 1 Failed download:
# - CBDE: No data found, symbol may be delisted
# 454 : CBF,
# 1 Failed download:
# - CBF: None
# 455 : CBFV,456 : CBIN,
# 1 Failed download:
# - CBIN: None
# 457 : CBLI,
# 1 Failed download:
# - CBLI: No data found, symbol may be delisted
# 458 : CBMG,
# 1 Failed download:
# - CBMG: No data found, symbol may be delisted
# 459 : CBMX,
# 1 Failed download:
# - CBMX: None
# 460 : CBNJ,
# 1 Failed download:
# - CBNJ: None
# 461 : CBNK,462 : CBOE,463 : CBPO,
# 1 Failed download:
# - CBPO: No data found, symbol may be delisted
# 464 : CBRL,465 : CBRX,
# 1 Failed download:
# - CBRX: None
# 466 : CBSH,467 : CBSHP,
# 1 Failed download:
# - CBSHP: No data found, symbol may be delisted
# 468 : CBST,
# 1 Failed download:
# - CBST: None
# 469 : CBSTZ,
# 1 Failed download:
# - CBSTZ: None
# 470 : CCBG,471 : CCCL,
# 1 Failed download:
# - CCCL: No data found, symbol may be delisted
# 472 : CCCR,
# 1 Failed download:
# - CCCR: None
# 473 : CCIH,474 : CCLP,475 : CCMP,476 : CCNE,477 : CCOI,478 : CCRN,479 : CCUR,480 : CCXI,481 : CDC,482 : CDK,483 : CDNA,484 : CDNS,485 : CDTI,486 : CDW,487 : CDXS,488 : CDZI,489 : CECE,490 : CECO,
# 1 Failed download:
# - CECO: No data found, symbol may be delisted
# 491 : CELG,
# 1 Failed download:
# - CELG: No data found, symbol may be delisted
# 492 : CELGZ,
# 1 Failed download:
# - CELGZ: No data found, symbol may be delisted
# 493 : CEMI,494 : CEMP,
# 1 Failed download:
# - CEMP: None
# 495 : CENT,496 : CENTA,497 : CENX,498 : CERE,499 : CERN,500 : CERS,501 : CERU,
# 1 Failed download:
# - CERU: None
# 502 : CETV,
# 1 Failed download:
# - CETV: No data found, symbol may be delisted
# 503 : CEVA,504 : CFA,505 : CFBK,506 : CFFI,507 : CFFN,508 : CFGE,
# 1 Failed download:
# - CFGE: None
# 509 : CFNB,510 : CFNL,
# 1 Failed download:
# - CFNL: None
# 511 : CFO,512 : CFRX,513 : CFRXW,
# 1 Failed download:
# - CFRXW: No data found, symbol may be delisted
# 514 : CFRXZ,
# 1 Failed download:
# - CFRXZ: No data found, symbol may be delisted
# 515 : CG,516 : CGEN,517 : CGIX,
# 1 Failed download:
# - CGIX: No data found, symbol may be delisted
# 518 : CGNX,519 : CGO,520 : CHCI,521 : CHCO,522 : CHDN,523 : CHEF,524 : CHEV,
# 1 Failed download:
# - CHEV: None
# 525 : CHFC,
# 1 Failed download:
# - CHFC: No data found, symbol may be delisted
# 526 : CHFN,
# 1 Failed download:
# - CHFN: No data found for this date range, symbol may be delisted
# 527 : CHI,528 : CHKE,
# 1 Failed download:
# - CHKE: None
# 529 : CHKP,530 : CHLN,
# 1 Failed download:
# - CHLN: None
# 531 : CHMG,532 : CHNR,533 : CHOP,
# 1 Failed download:
# - CHOP: None
# 534 : CHRS,535 : CHRW,536 : CHSCM,537 : CHSCN,538 : CHSCO,539 : CHSCP,540 : CHTR,541 : CHUY,542 : CHW,543 : CHXF,
# 1 Failed download:
# - CHXF: None
# 544 : CHY,545 : CHYR,
# 1 Failed download:
# - CHYR: None
# 546 : CIDM,547 : CIFC,
# 1 Failed download:
# - CIFC: None
# 548 : CIMT,
# 1 Failed download:
# - CIMT: None
# 549 : CINF,550 : CISAW,
# 1 Failed download:
# - CISAW: No data found, symbol may be delisted
# 551 : CISG,
# 1 Failed download:
# - CISG: None
# 552 : CIZ,553 : CIZN,554 : CJJD,555 : CKEC,
# 1 Failed download:
# - CKEC: None
# 556 : CKSW,
# 1 Failed download:
# - CKSW: None
# 557 : CLAC,
# 1 Failed download:
# - CLAC: None
# 558 : CLACU,
# 1 Failed download:
# - CLACU: None
# 559 : CLACW,
# 1 Failed download:
# - CLACW: No data found, symbol may be delisted
# 560 : CLBH,
# 1 Failed download:
# - CLBH: None
# 561 : CLCT,
# 1 Failed download:
# - CLCT: No data found, symbol may be delisted
# 562 : CLDN,
# 1 Failed download:
# - CLDN: None
# 563 : CLDX,564 : CLFD,565 : CLIR,566 : CLMS,
# 1 Failed download:
# - CLMS: None
# 567 : CLMT,568 : CLNE,569 : CLNT,
# 1 Failed download:
# - CLNT: None
# 570 : CLRB,571 : CLRBW,
# 1 Failed download:
# - CLRBW: No data found, symbol may be delisted
# 572 : CLRO,573 : CLRX,
# 1 Failed download:
# - CLRX: None
# 574 : CLSN,575 : CLTX,
# 1 Failed download:
# - CLTX: None
# 576 : CLUB,
# 1 Failed download:
# - CLUB: No data found, symbol may be delisted
# 577 : CLVS,578 : CLWT,579 : CMCO,580 : CMCSA,581 : CMCSK,
# 1 Failed download:
# - CMCSK: None
# 582 : CMCT,583 : CME,584 : CMFN,
# 1 Failed download:
# - CMFN: No data found, symbol may be delisted
# 585 : CMGE,
# 1 Failed download:
# - CMGE: None
# 586 : CMLS,587 : CMPR,588 : CMRX,589 : CMSB,
# 1 Failed download:
# - CMSB: None
# 590 : CMTL,591 : CNAT,
# 1 Failed download:
# - CNAT: No data found, symbol may be delisted
# 592 : CNBKA,593 : CNCE,594 : CNDO,
# 1 Failed download:
# - CNDO: None
# 595 : CNET,596 : CNIT,
# 1 Failed download:
# - CNIT: None
# 597 : CNLM,
# 1 Failed download:
# - CNLM: None
# 598 : CNLMR,
# 1 Failed download:
# - CNLMR: No data found, symbol may be delisted
# 599 : CNLMU,
# 1 Failed download:
# - CNLMU: No data found, symbol may be delisted
# 600 : CNLMW,
# 1 Failed download:
# - CNLMW: No data found, symbol may be delisted
# 601 : CNMD,602 : CNOB,603 : CNSI,
# 1 Failed download:
# - CNSI: None
# 604 : CNSL,605 : CNTF,
# 1 Failed download:
# - CNTF: No data found, symbol may be delisted
# 606 : CNTY,607 : CNV,
# 1 Failed download:
# - CNV: None
# 608 : CNXR,
# 1 Failed download:
# - CNXR: No data found for this date range, symbol may be delisted
# 609 : CNYD,
# 1 Failed download:
# - CNYD: None
# 610 : COB,
# 1 Failed download:
# - COB: None
# 611 : COBK,
# 1 Failed download:
# - COBK: None
# 612 : COBZ,
# 1 Failed download:
# - COBZ: No data found for this date range, symbol may be delisted
# 613 : COCO,
# 1 Failed download:
# - COCO: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 614 : COHR,615 : COHU,616 : COKE,617 : COLB,618 : COLM,619 : COMM,620 : COMT,621 : CONE,622 : CONN,623 : COOL,
# 1 Failed download:
# - COOL: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 624 : CORE,
# 1 Failed download:
# - CORE: No data found, symbol may be delisted
# 625 : CORI,
# 1 Failed download:
# - CORI: No data found for this date range, symbol may be delisted
# 626 : CORT,627 : COSI,
# 1 Failed download:
# - COSI: None
# 628 : COST,629 : COVS,
# 1 Failed download:
# - COVS: None
# 630 : COWN,631 : COWNL,632 : CPAH,
# 1 Failed download:
# - CPAH: No data found, symbol may be delisted
# 633 : CPGI,
# 1 Failed download:
# - CPGI: None
# 634 : CPHC,635 : CPHD,
# 1 Failed download:
# - CPHD: None
# 636 : CPHR,
# 1 Failed download:
# - CPHR: No data found, symbol may be delisted
# 637 : CPIX,638 : CPLA,
# 1 Failed download:
# - CPLA: No data found for this date range, symbol may be delisted
# 639 : CPLP,640 : CPRT,641 : CPRX,642 : CPSI,643 : CPSS,644 : CPST,
# 1 Failed download:
# - CPST: No data found, symbol may be delisted
# 645 : CPTA,
# 1 Failed download:
# - CPTA: No data found, symbol may be delisted
# 646 : CPXX,
# 1 Failed download:
# - CPXX: None
# 647 : CRAI,648 : CRAY,
# 1 Failed download:
# - CRAY: No data found, symbol may be delisted
# 649 : CRDC,
# 1 Failed download:
# - CRDC: None
# 650 : CRDS,
# 1 Failed download:
# - CRDS: None
# 651 : CRDT,
# 1 Failed download:
# - CRDT: None
# 652 : CREE,
# 1 Failed download:
# - CREE: No data found, symbol may be delisted
# 653 : CREG,654 : CRESW,
# 1 Failed download:
# - CRESW: No data found for this date range, symbol may be delisted
# 655 : CRESY,656 : CRIS,657 : CRME,
# 1 Failed download:
# - CRME: None
# 658 : CRMT,659 : CRNT,660 : CROX,661 : CRRC,
# 1 Failed download:
# - CRRC: None
# 662 : CRRS,
# 1 Failed download:
# - CRRS: None
# 663 : CRTN,
# 1 Failed download:
# - CRTN: No data found for this date range, symbol may be delisted
# 664 : CRTO,665 : CRUS,666 : CRVL,667 : CRWN,
# 1 Failed download:
# - CRWN: None
# 668 : CRWS,669 : CRZO,
# 1 Failed download:
# - CRZO: No data found, symbol may be delisted
# 670 : CSBK,
# 1 Failed download:
# - CSBK: No data found for this date range, symbol may be delisted
# 671 : CSCD,
# 1 Failed download:
# - CSCD: None
# 672 : CSCO,673 : CSF,674 : CSFL,
# 1 Failed download:
# - CSFL: No data found, symbol may be delisted
# 675 : CSGP,676 : CSGS,677 : CSII,678 : CSIQ,679 : CSOD,
# 1 Failed download:
# - CSOD: No data found, symbol may be delisted
# 680 : CSPI,681 : CSQ,682 : CSRE,
# 1 Failed download:
# - CSRE: None
# 683 : CSTE,684 : CSUN,
# 1 Failed download:
# - CSUN: None
# 685 : CSWC,686 : CTAS,687 : CTBI,688 : CTCM,
# 1 Failed download:
# - CTCM: None
# 689 : CTCT,
# 1 Failed download:
# - CTCT: None
# 690 : CTG,691 : CTHR,692 : CTIB,693 : CTIC,694 : CTRE,695 : CTRL,
# 1 Failed download:
# - CTRL: No data found, symbol may be delisted
# 696 : CTRN,697 : CTRP,
# 1 Failed download:
# - CTRP: No data found, symbol may be delisted
# 698 : CTRX,
# 1 Failed download:
# - CTRX: None
# 699 : CTSH,700 : CTSO,701 : CTWS,
# 1 Failed download:
# - CTWS: No data found, symbol may be delisted
# 702 : CTXS,703 : CU,
# 1 Failed download:
# - CU: None
# 704 : CUBA,705 : CUI,
# 1 Failed download:
# - CUI: No data found, symbol may be delisted
# 706 : CUNB,
# 1 Failed download:
# - CUNB: None
# 707 : CUTR,708 : CVBF,709 : CVCO,710 : CVCY,711 : CVGI,712 : CVGW,713 : CVLT,714 : CVLY,715 : CVTI,
# 1 Failed download:
# - CVTI: No data found, symbol may be delisted
# 716 : CVV,717 : CWAY,
# 1 Failed download:
# - CWAY: No data found for this date range, symbol may be delisted
# 718 : CWBC,719 : CWCO,720 : CWST,721 : CXDC,722 : CY,
# 1 Failed download:
# - CY: No data found, symbol may be delisted
# 723 : CYAN,724 : CYBE,725 : CYBR,726 : CYBX,
# 1 Failed download:
# - CYBX: None
# 727 : CYCC,728 : CYCCP,729 : CYHHZ,
# 1 Failed download:
# - CYHHZ: No data found, symbol may be delisted
# 730 : CYNO,
# 1 Failed download:
# - CYNO: None
# 731 : CYOU,
# 1 Failed download:
# - CYOU: No data found, symbol may be delisted
# 732 : CYRN,733 : CYTK,734 : CYTR,735 : CYTX,
# 1 Failed download:
# - CYTX: No data found, symbol may be delisted
# 736 : CZFC,
# 1 Failed download:
# - CZFC: No data found, symbol may be delisted
# 737 : CZNC,738 : CZR,739 : CZWI,740 : DAEG,
# 1 Failed download:
# - DAEG: None
# 741 : DAIO,742 : DAKT,743 : DARA,
# 1 Failed download:
# - DARA: None
# 744 : DATE,
# 1 Failed download:
# - DATE: None
# 745 : DAVE,
# 1 Failed download:
# - DAVE: No data found, symbol may be delisted
# 746 : DAX,747 : DBVT,748 : DCIX,
# 1 Failed download:
# - DCIX: No data found, symbol may be delisted
# 749 : DCOM,750 : DCTH,751 : DENN,752 : DEPO,
# 1 Failed download:
# - DEPO: None
# 753 : DERM,
# 1 Failed download:
# - DERM: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 754 : DEST,
# 1 Failed download:
# - DEST: No data found, symbol may be delisted
# 755 : DFRG,
# 1 Failed download:
# - DFRG: No data found, symbol may be delisted
# 756 : DFVL,757 : DFVS,758 : DGAS,
# 1 Failed download:
# - DGAS: None
# 759 : DGICA,760 : DGICB,761 : DGII,762 : DGLD,
# 1 Failed download:
# - DGLD: No data found, symbol may be delisted
# 763 : DGLY,764 : DGRE,765 : DGRS,766 : DGRW,767 : DHIL,768 : DHRM,
# 1 Failed download:
# - DHRM: None
# 769 : DIOD,770 : DISCA,771 : DISCB,772 : DISCK,773 : DISH,774 : DJCO,775 : DLBL,
# 1 Failed download:
# - DLBL: None
# 776 : DLBS,777 : DLHC,778 : DLTR,779 : DMLP,780 : DMND,
# 1 Failed download:
# - DMND: None
# 781 : DMRC,782 : DNBF,
# 1 Failed download:
# - DNBF: No data found, symbol may be delisted
# 783 : DNKN,
# 1 Failed download:
# - DNKN: No data found, symbol may be delisted
# 784 : DORM,785 : DOVR,
# 1 Failed download:
# - DOVR: None
# 786 : DOX,787 : DPRX,
# 1 Failed download:
# - DPRX: None
# 788 : DRAD,
# 1 Failed download:
# - DRAD: No data found, symbol may be delisted
# 789 : DRAM,
# 1 Failed download:
# - DRAM: None
# 790 : DRIV,791 : DRNA,792 : DRRX,793 : DRWI,
# 1 Failed download:
# - DRWI: None
# 794 : DRWIW,
# 1 Failed download:
# - DRWIW: No data found, symbol may be delisted
# 795 : DRYS,
# 1 Failed download:
# - DRYS: No data found, symbol may be delisted
# 796 : DSCI,
# 1 Failed download:
# - DSCI: None
# 797 : DSCO,
# 1 Failed download:
# - DSCO: None
# 798 : DSGX,799 : DSKX,
# 1 Failed download:
# - DSKX: No data found, symbol may be delisted
# 800 : DSKY,
# 1 Failed download:
# - DSKY: None
# 801 : DSLV,802 : DSPG,803 : DSWL,804 : DTLK,
# 1 Failed download:
# - DTLK: None
# 805 : DTSI,
# 1 Failed download:
# - DTSI: None
# 806 : DTUL,807 : DTUS,808 : DTV,
# 1 Failed download:
# - DTV: No data found, symbol may be delisted
# 809 : DTYL,810 : DTYS,811 : DVAX,812 : DVCR,813 : DWA,
# 1 Failed download:
# - DWA: None
# 814 : DWAT,815 : DWCH,
# 1 Failed download:
# - DWCH: No data found for this date range, symbol may be delisted
# 816 : DWSN,817 : DXCM,818 : DXGE,819 : DXJS,820 : DXKW,
# 1 Failed download:
# - DXKW: No data found, symbol may be delisted
# 821 : DXLG,822 : DXM,
# 1 Failed download:
# - DXM: None
# 823 : DXPE,824 : DXPS,
# 1 Failed download:
# - DXPS: No data found, symbol may be delisted
# 825 : DXYN,826 : DYAX,
# 1 Failed download:
# - DYAX: None
# 827 : DYNT,828 : DYSL,829 : EA,830 : EAC,
# 1 Failed download:
# - EAC: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 831 : EARS,
# 1 Failed download:
# - EARS: No data found, symbol may be delisted
# 832 : EBAY,833 : EBIO,
# 1 Failed download:
# - EBIO: None
# 834 : EBIX,835 : EBMT,836 : EBSB,837 : EBTC,838 : ECHO,839 : ECOL,840 : ECPG,841 : ECTE,
# 1 Failed download:
# - ECTE: No data found, symbol may be delisted
# 842 : ECYT,
# 1 Failed download:
# - ECYT: No data found for this date range, symbol may be delisted
# 843 : EDAP,844 : EDGW,
# 1 Failed download:
# - EDGW: No data found for this date range, symbol may be delisted
# 845 : EDS,
# 1 Failed download:
# - EDS: None
# 846 : EDUC,847 : EEFT,848 : EEI,
# 1 Failed download:
# - EEI: No data found, symbol may be delisted
# 849 : EEMA,850 : EEME,
# 1 Failed download:
# - EEME: None
# 851 : EEML,
# 1 Failed download:
# - EEML: No data found, symbol may be delisted
# 852 : EFII,
# 1 Failed download:
# - EFII: No data found, symbol may be delisted
# 853 : EFOI,854 : EFSC,855 : EFUT,
# 1 Failed download:
# - EFUT: None
# 856 : EGAN,857 : EGBN,858 : EGHT,859 : EGLE,860 : EGLT,
# 1 Failed download:
# - EGLT: No data found, symbol may be delisted
# 861 : EGOV,
# 1 Failed download:
# - EGOV: No data found, symbol may be delisted
# 862 : EGRW,
# 1 Failed download:
# - EGRW: None
# 863 : EGRX,864 : EGT,
# 1 Failed download:
# - EGT: None
# 865 : EHTH,866 : EIGI,
# 1 Failed download:
# - EIGI: No data found, symbol may be delisted
# 867 : ELGX,
# 1 Failed download:
# - ELGX: No data found, symbol may be delisted
# 868 : ELNK,
# 1 Failed download:
# - ELNK: None
# 869 : ELON,
# 1 Failed download:
# - ELON: No data found for this date range, symbol may be delisted
# 870 : ELOS,
# 1 Failed download:
# - ELOS: None
# 871 : ELRC,
# 1 Failed download:
# - ELRC: None
# 872 : ELSE,873 : ELTK,874 : EMCB,875 : EMCF,876 : EMCG,877 : EMCI,
# 1 Failed download:
# - EMCI: No data found, symbol may be delisted
# 878 : EMDI,
# 1 Failed download:
# - EMDI: None
# 879 : EMEY,
# 1 Failed download:
# - EMEY: None
# 880 : EMIF,881 : EMITF,882 : EMKR,883 : EML,884 : EMMS,885 : EMMSP,
# 1 Failed download:
# - EMMSP: None
# 886 : ENDP,887 : ENFC,
# 1 Failed download:
# - ENFC: No data found, symbol may be delisted
# 888 : ENG,889 : ENOC,
# 1 Failed download:
# - ENOC: None
# 890 : ENPH,891 : ENSG,892 : ENT,
# 1 Failed download:
# - ENT: No data found, symbol may be delisted
# 893 : ENTA,894 : ENTG,895 : ENTR,896 : ENVI,
# 1 Failed download:
# - ENVI: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 897 : ENZN,898 : ENZY,
# 1 Failed download:
# - ENZY: None
# 899 : EOPN,
# 1 Failed download:
# - EOPN: None
# 900 : EPAX,
# 1 Failed download:
# - EPAX: None
# 901 : EPAY,902 : EPIQ,
# 1 Failed download:
# - EPIQ: None
# 903 : EPRS,
# 1 Failed download:
# - EPRS: None
# 904 : EPZM,905 : EQIX,906 : ERI,
# 1 Failed download:
# - ERI: No data found, symbol may be delisted
# 907 : ERIC,908 : ERIE,909 : ERII,910 : EROC,
# 1 Failed download:
# - EROC: None
# 911 : ERS,
# 1 Failed download:
# - ERS: None
# 912 : ERW,
# 1 Failed download:
# - ERW: No data found, symbol may be delisted
# 913 : ESBF,
# 1 Failed download:
# - ESBF: None
# 914 : ESBK,915 : ESCA,916 : ESCR,917 : ESCRP,
# 1 Failed download:
# - ESCRP: No data found, symbol may be delisted
# 918 : ESEA,919 : ESGR,920 : ESIO,
# 1 Failed download:
# - ESIO: No data found for this date range, symbol may be delisted
# 921 : ESLT,922 : ESMC,923 : ESPR,924 : ESRX,
# 1 Failed download:
# - ESRX: No data found for this date range, symbol may be delisted
# 925 : ESSA,926 : ESSX,
# 1 Failed download:
# - ESSX: None
# 927 : ESXB,928 : ESYS,
# 1 Failed download:
# - ESYS: None
# 929 : ETFC,
# 1 Failed download:
# - ETFC: No data found, symbol may be delisted
# 930 : ETRM,
# 1 Failed download:
# - ETRM: None
# 931 : EUFN,932 : EVAL,
# 1 Failed download:
# - EVAL: None
# 933 : EVAR,
# 1 Failed download:
# - EVAR: None
# 934 : EVBS,
# 1 Failed download:
# - EVBS: None
# 935 : EVEP,
# 1 Failed download:
# - EVEP: None
# 936 : EVK,937 : EVLV,938 : EVOK,939 : EVOL,940 : EVRY,
# 1 Failed download:
# - EVRY: None
# 941 : EWBC,942 : EXA,
# 1 Failed download:
# - EXA: None
# 943 : EXAC,
# 1 Failed download:
# - EXAC: No data found for this date range, symbol may be delisted
# 944 : EXAS,945 : EXEL,946 : EXFO,
# 1 Failed download:
# - EXFO: No data found, symbol may be delisted
# 947 : EXLP,
# 1 Failed download:
# - EXLP: None
# 948 : EXLS,949 : EXPD,950 : EXPE,951 : EXPO,952 : EXTR,953 : EXXI,
# 1 Failed download:
# - EXXI: None
# 954 : EYES,955 : EZCH,
# 1 Failed download:
# - EZCH: None
# 956 : EZPW,957 : FALC,958 : FANG,959 : FARM,960 : FARO,961 : FAST,962 : FATE,963 : FB,964 : FBIZ,965 : FBMS,966 : FBNC,967 : FBNK,
# 1 Failed download:
# - FBNK: No data found, symbol may be delisted
# 968 : FBRC,
# 1 Failed download:
# - FBRC: None
# 969 : FBSS,
# 1 Failed download:
# - FBSS: No data found, symbol may be delisted
# 970 : FCAP,971 : FCBC,972 : FCCO,973 : FCCY,974 : FCEL,975 : FCFS,976 : FCHI,
# 1 Failed download:
# - FCHI: No data found, symbol may be delisted
# 977 : FCLF,
# 1 Failed download:
# - FCLF: None
# 978 : FCNCA,979 : FCS,
# 1 Failed download:
# - FCS: None
# 980 : FCSC,
# 1 Failed download:
# - FCSC: No data found, symbol may be delisted
# 981 : FCTY,
# 1 Failed download:
# - FCTY: None
# 982 : FCVA,
# 1 Failed download:
# - FCVA: None
# 983 : FCZA,
# 1 Failed download:
# - FCZA: None
# 984 : FCZAP,
# 1 Failed download:
# - FCZAP: No data found, symbol may be delisted
# 985 : FDEF,
# 1 Failed download:
# - FDEF: No data found, symbol may be delisted
# 986 : FDIV,987 : FDML,
# 1 Failed download:
# - FDML: None
# 988 : FDUS,989 : FEIC,
# 1 Failed download:
# - FEIC: None
# 990 : FEIM,991 : FELE,992 : FEMB,993 : FES,
# 1 Failed download:
# - FES: None
# 994 : FEUZ,995 : FEYE,
# 1 Failed download:
# - FEYE: No data found, symbol may be delisted
# 996 : FFBC,997 : FFBCW,
# 1 Failed download:
# - FFBCW: No data found, symbol may be delisted
# 998 : FFHL,999 : FFIC,1000 : FFIN,1001 : FFIV,1002 : FFKT,
# 1 Failed download:
# - FFKT: No data found for this date range, symbol may be delisted
# 1003 : FFNM,
# 1 Failed download:
# - FFNM: No data found for this date range, symbol may be delisted
# 1004 : FFNW,1005 : FFWM,1006 : FGEN,1007 : FHCO,
# 1 Failed download:
# - FHCO: None
# 1008 : FIBK,1009 : FINL,
# 1 Failed download:
# - FINL: No data found for this date range, symbol may be delisted
# 1010 : FISH,
# 1 Failed download:
# - FISH: None
# 1011 : FISI,1012 : FISV,1013 : FITB,1014 : FITBI,1015 : FIVE,1016 : FIVN,1017 : FIZZ,1018 : FLAT,1019 : FLDM,1020 : FLEX,1021 : FLIC,1022 : FLIR,
# 1 Failed download:
# - FLIR: No data found, symbol may be delisted
# 1023 : FLL,1024 : FLML,
# 1 Failed download:
# - FLML: None
# 1025 : FLWS,1026 : FLXN,1027 : FLXS,1028 : FMB,1029 : FMBH,1030 : FMBI,1031 : FMER,
# 1 Failed download:
# - FMER: None
# 1032 : FMI,
# 1 Failed download:
# - FMI: No data found for this date range, symbol may be delisted
# 1033 : FMNB,1034 : FNBC,
# 1 Failed download:
# - FNBC: None
# 1035 : FNFG,
# 1 Failed download:
# - FNFG: None
# 1036 : FNGN,
# 1 Failed download:
# - FNGN: No data found, symbol may be delisted
# 1037 : FNHC,1038 : FNJN,
# 1 Failed download:
# - FNJN: No data found, symbol may be delisted
# 1039 : FNLC,1040 : FNRG,
# 1 Failed download:
# - FNRG: No data found for this date range, symbol may be delisted
# 1041 : FNSR,
# 1 Failed download:
# - FNSR: No data found, symbol may be delisted
# 1042 : FOLD,1043 : FOMX,
# 1 Failed download:
# - FOMX: No data found, symbol may be delisted
# 1044 : FONE,
# 1 Failed download:
# - FONE: None
# 1045 : FONR,1046 : FORD,1047 : FORM,1048 : FORR,1049 : FORTY,1050 : FOSL,1051 : FOX,1052 : FOXA,1053 : FOXF,1054 : FPRX,
# 1 Failed download:
# - FPRX: No data found, symbol may be delisted
# 1055 : FPXI,1056 : FRAN,
# 1 Failed download:
# - FRAN: No data found, symbol may be delisted
# 1057 : FRBA,1058 : FRBK,1059 : FRED,
# 1 Failed download:
# - FRED: No data found, symbol may be delisted
# 1060 : FREE,1061 : FRGI,1062 : FRME,1063 : FRP,
# 1 Failed download:
# - FRP: None
# 1064 : FRPH,1065 : FRPHV,
# 1 Failed download:
# - FRPHV: No data found, symbol may be delisted
# 1066 : FRPT,1067 : FRSH,
# 1 Failed download:
# - FRSH: Data doesn't exist for startDate = 1580544000, endDate = 1602399600
# 1068 : FSAM,
# 1 Failed download:
# - FSAM: No data found, symbol may be delisted
# 1069 : FSBK,
# 1 Failed download:
# - FSBK: None
# 1070 : FSBW,1071 : FSC,
# 1 Failed download:
# - FSC: None
# 1072 : FSCFL,
# 1 Failed download:
# - FSCFL: No data found, symbol may be delisted
# 1073 : FSFG,1074 : FSFR,
# 1 Failed download:
# - FSFR: None
# 1075 : FSGI,
# 1 Failed download:
# - FSGI: None
# 1076 : FSLR,1077 : FSNN,
# 1 Failed download:
# - FSNN: No data found, symbol may be delisted
# 1078 : FSRV,
# 1 Failed download:
# - FSRV: No data found, symbol may be delisted
# 1079 : FSTR,1080 : FSYS,
# 1 Failed download:
# - FSYS: None
# 1081 : FTCS,1082 : FTD,
# 1 Failed download:
# - FTD: No data found, symbol may be delisted
# 1083 : FTEK,1084 : FTGC,1085 : FTHI,1086 : FTLB,1087 : FTNT,1088 : FTR,
# 1 Failed download:
# - FTR: No data found, symbol may be delisted
# 1089 : FTSL,1090 : FTSM,1091 : FUEL,
# 1 Failed download:
# - FUEL: None
# 1092 : FULL,
# 1 Failed download:
# - FULL: None
# 1093 : FULLL,
# 1 Failed download:
# - FULLL: No data found, symbol may be delisted
# 1094 : FULT,1095 : FUNC,1096 : FUND,1097 : FV,1098 : FWM,
# 1 Failed download:
# - FWM: None
# 1099 : FWP,1100 : FWRD,1101 : FXCB,
# 1 Failed download:
# - FXCB: None
# 1102 : FXEN,
# 1 Failed download:
# - FXEN: None
# 1103 : FXENP,
# 1 Failed download:
# - FXENP: No data found, symbol may be delisted
# 1104 : GABC,
# Exception in thread Thread-1111:
# Traceback (most recent call last):
#   File "/home/pookie/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/pookie/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pookie/anaconda3/lib/python3.8/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/home/pookie/anaconda3/lib/python3.8/site-packages/yfinance/multi.py", line 169, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/pookie/anaconda3/lib/python3.8/site-packages/yfinance/multi.py", line 181, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/pookie/anaconda3/lib/python3.8/site-packages/yfinance/base.py", line 159, in history
#     raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
# RuntimeError: *** YAHOO! FINANCE IS CURRENTLY DOWN! ***
# Our engineers are working quickly to resolve the issue. Thank you for your patience.

# %%
stock_final.head()
